# %% [markdown]
# # <center>LAB 7 - Model
#
# ---------------------------
#
# Name: **KRISH GOYAL** <br>
# Reg No: **21112015** <br>
# Class: **4 BSC DS** <br>
#
# ---------------
#
# <u>**Objectives**</u>
# - Make two classification datasets, having more than 50% informative features and a minimum of 2500 rows (4 Marks)
# - Do some kind of Scaling on the first 5 features (4 Marks)
# - Compare the suitability of above datasets when performing Logistic Regression and Support Vector Machines (5 Marks)
# - Check whether the applied transformation have an impact on the final quality of Classification Model, and present your findings neatly (7 Marks)
#
# -------------------
#
# <u> **Problem Statement**</u>
# - To compare the different accuracies of the model of two different datasets.
#
# -----------------
#
#
# <u>**Methods**</u>
# - **make_classification()**
# - **LogisticRegression()**
# - **SVM()**
#
# ------------------
#
# <u>**Observations**</u>
# - First Dataset being made.
# - Second Dataset being made.
# - Both the dataset were having different values and after scaling they are being scaled with informative features which increases the relevancy & accuracy of the model.
# - In first Dataset | Logistic Regression Accuracy is 95%. | SVM Accuracy is 98%.
# - In Second Dataset |  Logistic Regression Accuracy is 87%. | SVM Accuracy is 95%.
# - As in the first dataset generated we have given the parameters for generation so after scalling there is no much or significant change. -- Therefore , | Accuracy of unscaled data: 94.53%  | Accuracy of scaled data: 94.93%
# - As in the second dataset generated we have given the parameters for generation so after scalling there is no much or significant change. -- Therefore , | Accuracy of unscaled data: 87.07%  | Accuracy of scaled data: 87.07%
# - The values of the features are showing generally a postive correlation.
#
# ------------------
#
# <u>**Results**</u>
# - Comparing the suitability of classification datasets when performing Logistic Regression and Support Vector Machines
#
# ------------------
#
# <u>**Learnings & Reflection**</u>
# - The different datasets have two different accuracies for each SVM and Logistic Regression.
#
# ------------------
#
# <u>**References**</u> <br>
# 1. [Pandas Documendation](https://pandas.pydata.org/)<br>
# 2. [Sklearn Classifation](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html)<br>
# 3. [Model Selection](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html)
#
# ***************
#
# [Github Link](https://github.com/Krishnaa-tech/ML-Projects.git)<br>
# ------------------

# %% [markdown]
# <u><center>**Completion Status**</u>
#
# | Question Number | Status |
# |---|---|
# | 1 | Completed |
# | 2 | Completed |
# | 3 | Completed |
# | 4 | Completed |

# %%
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold, cross_val_score
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
fig = plt.figure()

X,y = make_classification(n_samples=2500, n_features=10, n_informative=7, 
                    n_redundant=0, n_repeated=0, n_classes=3, n_clusters_per_class=2,
                          class_sep=1.5,
                   flip_y=0,weights=[0.5,0.5,0.5])
X = pd.DataFrame(X)
y = pd.Series(y)

# %%
X.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.732492 -0.137244  0.610381  0.344714  2.273664  1.070319  2.488385
# 1 -2.981429  0.446149  2.961727 -1.043515 -3.107832  1.568889 -0.764374
# 2  0.724850  1.295771  1.335029 -2.298496  1.414349 -0.280880  0.470622
# 3 -1.967291  1.549387  2.398505 -0.635536 -2.723865  3.822178 -0.609632
# 4 -1.746040 -0.978895 -1.602209  1.029112 -4.547729  2.216728 -0.996512
#
#           7         8         9
# 0  0.869551 -1.540108 -3.282518
# 1  0.913069 -2.009816 -0.106230
# 2  0.093539  0.909566  2.885487
# 3  1.552144 -0.192107 -2.410362
# 4  1.027294 -1.283875 -4.305935

# %%
print(X.shape[0])
# Out:
# 2500

# %%
X.columns = ['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4',
                             'Feature 5', 'Feature 6', 'Feature 7', 'Feature 8',
                             'Feature 9', 'Feature 10']

# %%
X
# Out:
#       Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 0      1.732492  -0.137244   0.610381   0.344714   2.273664   1.070319
# 1     -2.981429   0.446149   2.961727  -1.043515  -3.107832   1.568889
# 2      0.724850   1.295771   1.335029  -2.298496   1.414349  -0.280880
# 3     -1.967291   1.549387   2.398505  -0.635536  -2.723865   3.822178
# 4     -1.746040  -0.978895  -1.602209   1.029112  -4.547729   2.216728
# ...         ...        ...        ...        ...        ...        ...
# 2495   1.891910  -0.551168  -0.584903  -2.946961  -4.030680  -3.069476
# 2496   1.053694  -1.011462   2.292001  -3.194643   2.341508   0.972802
# 2497  -1.172406  -1.627244  -0.693096   2.244949  -1.458163  -0.613614
# 2498   0.480064  -1.393203   1.883429  -2.970156   1.607331  -0.104423
# 2499  -0.250610  -1.435469  -0.730235   2.294914  -0.942219   0.655736
#
#       Feature 7  Feature 8  Feature 9  Feature 10
# 0      2.488385   0.869551  -1.540108   -3.282518
# ...

# %% [markdown]
# **Observation** - *First Dataset being made.*

# %%
scaler = StandardScaler()
X.iloc[:, :5] = scaler.fit_transform(X.iloc[:, :5])

# %%
X
# Out:
#       Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 0      1.189965  -0.125479  -0.067346   0.580509   1.327855   1.070319
# 1     -1.018261   0.463919   1.202672  -0.161636  -1.091204   1.568889
# 2      0.717937   1.322287   0.324054  -0.832547   0.941581  -0.280880
# 3     -0.543190   1.578513   0.898463   0.056469  -0.918606   3.822178
# 4     -0.439546  -0.975793  -1.262418   0.946387  -1.738458   2.216728
# ...         ...        ...        ...        ...        ...        ...
# 2495   1.264644  -0.543663  -0.712947  -1.179215  -1.506038  -3.069476
# 2496   0.871983  -1.008696   0.840937  -1.311626   1.358351   0.972802
# 2497  -0.170828  -1.630816  -0.771385   1.596372  -0.349654  -0.613614
# 2498   0.603268  -1.394366   0.620258  -1.191615   1.028329  -0.104423
# 2499   0.260985  -1.437067  -0.791444   1.623083  -0.117730   0.655736
#
#       Feature 7  Feature 8  Feature 9  Feature 10
# 0      2.488385   0.869551  -1.540108   -3.282518
# ...

# %% [markdown]
# **Observation** - *The first five columns being scaled using Standard Scalar*

# %%
fig = plt.figure()

X1,y1 = make_classification(n_samples=2500, n_features=10, n_informative=7, 
                    n_redundant=0, n_repeated=0, n_classes=3, n_clusters_per_class=2,
                          class_sep=1.5,
                   flip_y=0,weights=[0.5,0.5,0.5])
X1 = pd.DataFrame(X1)
y1 = pd.Series(y1)

# %%
X1.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.259365  1.258525  0.748227 -3.144622  1.395723 -1.037669  1.159517
# 1 -3.937454  1.800889  1.025119 -3.811803  1.888919  0.020633 -1.769025
# 2 -3.687156  2.368355 -0.166485  4.256241  2.932448 -0.926809 -2.539730
# 3 -1.137183  1.988220  0.025624 -0.475667  0.809434 -2.485149 -0.188640
# 4  0.157201  0.316087 -0.154155  0.114036  1.740216 -0.456779 -2.267358
#
#           7         8         9
# 0 -0.982869  0.850322  4.170786
# 1  0.280279 -0.711185  1.851191
# 2  0.802058 -0.556006 -0.139435
# 3 -1.406957 -1.355377  2.629464
# 4 -0.778642 -0.142032  0.684343

# %%
X1.columns = ['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4',
                             'Feature 5', 'Feature 6', 'Feature 7', 'Feature 8',
                             'Feature 9', 'Feature 10']

# %%
X1.head()
# Out:
#    Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 0  -1.259365   1.258525   0.748227  -3.144622   1.395723  -1.037669
# 1  -3.937454   1.800889   1.025119  -3.811803   1.888919   0.020633
# 2  -3.687156   2.368355  -0.166485   4.256241   2.932448  -0.926809
# 3  -1.137183   1.988220   0.025624  -0.475667   0.809434  -2.485149
# 4   0.157201   0.316087  -0.154155   0.114036   1.740216  -0.456779
#
#    Feature 7  Feature 8  Feature 9  Feature 10
# 0   1.159517  -0.982869   0.850322    4.170786
# 1  -1.769025   0.280279  -0.711185    1.851191
# 2  -2.539730   0.802058  -0.556006   -0.139435
# 3  -0.188640  -1.406957  -1.355377    2.629464
# 4  -2.267358  -0.778642  -0.142032    0.684343

# %% [markdown]
# **Observation** - *Second Dataset being made.*

# %%
scaler = StandardScaler()
X1.iloc[:, :5] = scaler.fit_transform(X1.iloc[:, :5])

# %%
X1
# Out:
#       Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 0      0.140923   0.281106  -0.474213  -1.426020   0.321413  -1.037669
# 1     -1.714335   0.576839  -0.300150  -1.729689   0.563096   0.020633
# 2     -1.540940   0.886259  -1.049232   1.942488   1.074461  -0.926809
# 3      0.225566   0.678984  -0.928466  -0.211243   0.034112  -2.485149
# 4      1.122256  -0.232773  -1.041481   0.057160   0.490227  -0.456779
# ...         ...        ...        ...        ...        ...        ...
# 2495   1.169887   0.458007   0.236915  -0.212350   0.095342   0.776852
# 2496  -0.598700   0.329952  -0.235116  -0.373676   0.514620   0.366129
# 2497   0.016662  -0.278406   0.145202  -0.991030   0.589258  -0.446417
# 2498   0.149434   1.286596  -0.087604  -0.662861   0.973078  -1.257916
# 2499  -1.065646   0.687708  -0.573005  -0.882781   0.076333   1.227417
#
#       Feature 7  Feature 8  Feature 9  Feature 10
# 0      1.159517  -0.982869   0.850322    4.170786
# ...

# %% [markdown]
# **Observation** - *The first five columns being scaled using Standard Scalar*`

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X ,y, test_size=0.3, random_state=42)

# Train a logistic regression model
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
lr_Score = accuracy_score(y_test, y_pred)

# Train an SVM model
svm = SVC()
svm.fit(X_train, y_train)
y_pred1 = svm.predict(X_test)
svm_accuracy = accuracy_score(y_test, y_pred1)

# Print the results
print('Logistic Regression Accuracy:', lr_Score*100)
print('SVM Accuracy:', svm_accuracy*100)
# Out:
# Logistic Regression Accuracy: 94.53333333333333
# SVM Accuracy: 97.6

# %% [markdown]
# **Observation** - *In first Dataset*
# - Logistic Regression Accuracy is 95%.
# - SVM Accuracy is 98%.

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
 kfold = KFold(n_splits=10)
 cv_results = cross_val_score(model, X, y, cv=kfold, scoring=scoring)
 results.append(cv_results)
 names.append(name)
 msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
 print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# LR: 0.952400 (0.010346)
# SVM: 0.977600 (0.005122)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X1 ,y1, test_size=0.3, random_state=42)

# Train a logistic regression model
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
lr_Score = accuracy_score(y_test, y_pred)

# Train an SVM model
svm = SVC()
svm.fit(X_train, y_train)
y_pred1 = svm.predict(X_test)
svm_accuracy = accuracy_score(y_test, y_pred1)

# Print the results
print('Logistic Regression Accuracy:', lr_Score*100)
print('SVM Accuracy:', svm_accuracy*100)
# Out:
# Logistic Regression Accuracy: 87.06666666666666
# SVM Accuracy: 94.93333333333334

# %% [markdown]
# **Observation** - *In Second Dataset*
# - Logistic Regression Accuracy is 87%.
# - SVM Accuracy is 95%.

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
 kfold = KFold(n_splits=10)
 cv_results = cross_val_score(model, X1, y1, cv=kfold, scoring=scoring)
 results.append(cv_results)
 names.append(name)
 msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
 print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# LR: 0.856800 (0.013482)
# SVM: 0.951600 (0.010346)

# %% [markdown]
# #### Final quality of Classification Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

logic1 = LogisticRegression(random_state=42)
logic1.fit(X_train, y_train)
y_predic1 = logic1.predict(X_test)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

logic2 = LogisticRegression(random_state=42)
logic2.fit(X_train_scaled, y_train)
y_predic2 = logic2.predict(X_test_scaled)

# Comparing the accuracies of the two models
acc1 = accuracy_score(y_test, y_predic1)
acc2 = accuracy_score(y_test, y_predic2)

print("Accuracy of unscaled data: {:.2f}%".format(acc1*100))
print("Accuracy of scaled data: {:.2f}%".format(acc2*100))
# Out:
# Accuracy of unscaled data: 94.53%
# Accuracy of scaled data: 94.93%

# %% [markdown]
# **Observation** - *As in the first dataset generated we have given the parameters for generation so after scalling there is no much or significant change.*
# -- Therefore ,
# - Accuracy of unscaled data: 94.53%
# - Accuracy of scaled data: 94.93%

# %%
import seaborn as sns
sns.heatmap(data = X.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# **Observation** - *The values of the features are showing generally a postive correlation.*

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.3, random_state=42)

# Train a logistic regression model on the unscaled dataset
logic1 = LogisticRegression(random_state=42)
logic1.fit(X_train, y_train)
y_predic1 = logic1.predict(X_test)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

logic2 = LogisticRegression(random_state=42)
logic2.fit(X_train_scaled, y_train)
y_predic2 = logic2.predict(X_test_scaled)

# Compare the classification accuracy of the two models
acc1 = accuracy_score(y_test, y_predic1)
acc2 = accuracy_score(y_test, y_predic2)

print("Accuracy of unscaled data: {:.2f}%".format(acc1*100))
print("Accuracy of scaled data: {:.2f}%".format(acc2*100))
# Out:
# Accuracy of unscaled data: 87.07%
# Accuracy of scaled data: 87.07%

# %% [markdown]
# **Observation** - *As in the second dataset generated we have given the parameters for generation so after scalling there is no much or significant change.*
# -- Therefore ,
# - Accuracy of unscaled data: 87.07%
# - Accuracy of scaled data: 87.07%

# %%
import seaborn as sns
sns.heatmap(data = X1.corr(),annot= True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# **Observation** - *The values of the features are showing generally a postive correlation.*
